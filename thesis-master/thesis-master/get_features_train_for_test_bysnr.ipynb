# %%
import librosa
import sounddevice as sd
from pystoi.stoi import stoi
from librosa.core import stft, istft
import os
import h5py
from natsort import natsorted
import numpy as np
import math as m

# %%
import math as m

# %%
orig_path = 'D:/studies/university/thesis/speech_separation_codes/du16/donesomestuff'
i = 1
w = 3
data = os.listdir(os.path.join(orig_path,'lilmixed_bysnr'))
data = natsorted(data)

# %%
data
# Out:
# ['0', '3', '6', 'm3', 'm6', 'm9']

# %%
raw_folder = 'lilmixed_bysnr'
log_folder = 'train_log'
phase_folder = 'train_phase'
# a = os.listdir(os.path.join(orig_path,raw_folder))
# a = natsorted(a)
if not os.path.exists(os.path.normpath(os.path.join(orig_path,log_folder))):
    os.mkdir(os.path.normpath(os.path.join(orig_path,log_folder)))
if not os.path.exists(os.path.normpath(os.path.join(orig_path,phase_folder))):
    os.mkdir(os.path.normpath(os.path.join(orig_path,phase_folder)))
for filename in data:
    if filename!='clean':
        b = os.listdir(os.path.join(orig_path,raw_folder,filename))
        b = natsorted(b)[:20]
        if not os.path.exists(os.path.normpath(os.path.join(orig_path,log_folder,filename))):
            os.mkdir(os.path.normpath(os.path.join(orig_path,log_folder,filename)))
        if not os.path.exists(os.path.normpath(os.path.join(orig_path,phase_folder,filename))):
            os.mkdir(os.path.normpath(os.path.join(orig_path,phase_folder,filename)))
        for filename2 in b:
            wav_data, sr = librosa.load(os.path.join(orig_path,raw_folder)+"/"+filename+'/'+filename2, sr=16000) 
            framed_data=librosa.core.stft(wav_data, n_fft=512, hop_length=256, win_length=512, window='hann')
            abslt=np.absolute(framed_data)**2
            dft_signal=np.log10(abslt+1e-7*np.ones(np.shape(abslt)))
            for i in range(m.floor(w/2)):
                dft_signal=np.insert(dft_signal,0,0,axis = 1)
            data_phase=np.angle(framed_data)   
            print(str(filename2.replace('.wav','')))
            np.savetxt(os.path.join(orig_path,log_folder,str(filename),str(filename2.replace('.wav','.txt'))), dft_signal.T, delimiter=',')
            np.savetxt(os.path.join(orig_path,phase_folder,str(filename),str(filename2.replace('.wav','.txt'))), data_phase.T, delimiter=',')
# Out:
# mixed_bbaf3p_lwiy6n
# mixed_bbaf3p_pwag6n
# mixed_bbaf4a_lwiy6n
# mixed_bbaf4a_pwag6n
# mixed_bbal5n_lwiy6n
# mixed_bbal5n_pwag6n
# mixed_bbal6s_lwiy6n
# mixed_bbal6s_pwag6n
# mixed_bbas2a_lwiy6n
# mixed_bbas2a_pwag6n
# mixed_bbaszs_lwiy6n
# mixed_bbaszs_pwag6n
# mixed_bbaz5p_lwiy6n
# mixed_bbaz5p_pwag6n
# mixed_bbaz6a_lwiy6n
# mixed_bbaz6a_pwag6n
# mixed_bbbf5n_lwiy6n
# mixed_bbbf5n_pwag6n
# mixed_bbbl9n_lwiy6n
# mixed_bbbl9n_pwag6n
# mixed_bbaf3p_lwiy6n
# mixed_bbaf3p_pwag6n
# mixed_bbaf4a_lwiy6n
# mixed_bbaf4a_pwag6n
# mixed_bbal5n_lwiy6n
# mixed_bbal5n_pwag6n
# mixed_bbal6s_lwiy6n
# mixed_bbal6s_pwag6n
# mixed_bbas2a_lwiy6n
# mixed_bbas2a_pwag6n
# mixed_bbaszs_lwiy6n
# mixed_bbaszs_pwag6n
# mixed_bbaz5p_lwiy6n
# mixed_bbaz5p_pwag6n
# mixed_bbaz6a_lwiy6n
# mixed_bbaz6a_pwag6n
# mixed_bbbf5n_lwiy6n
# mixed_bbbf5n_pwag6n
# mixed_bbbl9n_lwiy6n
# mixed_bbbl9n_pwag6n
# mixed_bbaf3p_lwiy6n
# mixed_bbaf3p_pwag6n
# mixed_bbaf4a_lwiy6n
# mixed_bbaf4a_pwag6n
# mixed_bbal5n_lwiy6n
# mixed_bbal5n_pwag6n
# mixed_bbal6s_lwiy6n
# mixed_bbal6s_pwag6n
# mixed_bbas2a_lwiy6n
# mixed_bbas2a_pwag6n
# mixed_bbaszs_lwiy6n
# mixed_bbaszs_pwag6n
# mixed_bbaz5p_lwiy6n
# mixed_bbaz5p_pwag6n
# mixed_bbaz6a_lwiy6n
# mixed_bbaz6a_pwag6n
# mixed_bbbf5n_lwiy6n
# mixed_bbbf5n_pwag6n
# mixed_bbbl9n_lwiy6n
# mixed_bbbl9n_pwag6n
# mixed_bbaf3p_lwiy6n
# mixed_bbaf3p_pwag6n
# mixed_bbaf4a_lwiy6n
# mixed_bbaf4a_pwag6n
# mixed_bbal5n_lwiy6n
# mixed_bbal5n_pwag6n
# mixed_bbal6s_lwiy6n
# mixed_bbal6s_pwag6n
# mixed_bbas2a_lwiy6n
# mixed_bbas2a_pwag6n
# mixed_bbaszs_lwiy6n
# mixed_bbaszs_pwag6n
# mixed_bbaz5p_lwiy6n
# mixed_bbaz5p_pwag6n
# mixed_bbaz6a_lwiy6n
# mixed_bbaz6a_pwag6n
# mixed_bbbf5n_lwiy6n
# mixed_bbbf5n_pwag6n
# mixed_bbbl9n_lwiy6n
# mixed_bbbl9n_pwag6n
# mixed_bbaf3p_lwiy6n
# mixed_bbaf3p_pwag6n
# mixed_bbaf4a_lwiy6n
# mixed_bbaf4a_pwag6n
# mixed_bbal5n_lwiy6n
# mixed_bbal5n_pwag6n
# mixed_bbal6s_lwiy6n
# mixed_bbal6s_pwag6n
# mixed_bbas2a_lwiy6n
# mixed_bbas2a_pwag6n
# mixed_bbaszs_lwiy6n
# mixed_bbaszs_pwag6n
# mixed_bbaz5p_lwiy6n
# mixed_bbaz5p_pwag6n
# mixed_bbaz6a_lwiy6n
# mixed_bbaz6a_pwag6n
# mixed_bbbf5n_lwiy6n
# mixed_bbbf5n_pwag6n
# mixed_bbbl9n_lwiy6n
# mixed_bbbl9n_pwag6n
# mixed_bbaf3p_lwiy6n
# mixed_bbaf3p_pwag6n
# mixed_bbaf4a_lwiy6n
# mixed_bbaf4a_pwag6n
# mixed_bbal5n_lwiy6n
# mixed_bbal5n_pwag6n
# mixed_bbal6s_lwiy6n
# mixed_bbal6s_pwag6n
# mixed_bbas2a_lwiy6n
# mixed_bbas2a_pwag6n
# mixed_bbaszs_lwiy6n
# mixed_bbaszs_pwag6n
# mixed_bbaz5p_lwiy6n
# mixed_bbaz5p_pwag6n
# mixed_bbaz6a_lwiy6n
# mixed_bbaz6a_pwag6n
# mixed_bbbf5n_lwiy6n
# mixed_bbbf5n_pwag6n
# mixed_bbbl9n_lwiy6n
# mixed_bbbl9n_pwag6n

# %%
raw_folder = 'lilmixed_bysnr'
log_folder = 'train_log2'
phase_folder = 'train_phase2'
# a = os.listdir(os.path.join(orig_path,raw_folder))
# a = natsorted(a)
if not os.path.exists(os.path.normpath(os.path.join(orig_path,log_folder))):
    os.mkdir(os.path.normpath(os.path.join(orig_path,log_folder)))
if not os.path.exists(os.path.normpath(os.path.join(orig_path,phase_folder))):
    os.mkdir(os.path.normpath(os.path.join(orig_path,phase_folder)))
for filename in data:
    if filename!='clean':
        b = os.listdir(os.path.join(orig_path,raw_folder,filename))
        b = natsorted(b)[:20]
        if not os.path.exists(os.path.join(orig_path,log_folder,filename)):
            os.mkdir(os.path.join(orig_path,log_folder,filename))
        if not os.path.exists(os.path.join(orig_path,phase_folder ,filename)):
            os.mkdir(os.path.join(orig_path,phase_folder ,filename))
        for filename2 in b:
            wav_data, sr = librosa.load(os.path.join(orig_path,raw_folder,filename,filename2), sr=16000) 
            framed_data=librosa.core.stft(wav_data, n_fft=512, hop_length=256, win_length=512, window='hann')
            abslt=np.absolute(framed_data)**2
            dft_signal=np.log10(abslt+1e-7*np.ones(np.shape(abslt)))
            data_phase=np.angle(framed_data)    
            np.savetxt(os.path.join(orig_path,log_folder,filename,str(filename2.replace('.wav','.txt'))), dft_signal.T, delimiter=',')
            np.savetxt(os.path.join(orig_path,phase_folder ,filename,str(filename2.replace('.wav','.txt'))), data_phase.T, delimiter=',')

# %%
raw_folder = 'single_dataset_16'
log_folder = 'train_log'
phase_folder = 'train_phase'
b = os.listdir(os.path.join(orig_path,'lilmixed_bysnr','0'))
b = natsorted(b)
speaker='2'
num_of_snrs = 6
num_of_speakers = 2
a = os.listdir(os.path.join(orig_path,raw_folder,speaker))
a = natsorted(a)[0:10]
filename='clean'
if not os.path.exists(os.path.join(orig_path,log_folder,filename)):
    os.mkdir(os.path.join(orig_path,log_folder,filename))
wav = []
for filename2 in a:
    wav_data, sr = librosa.load(os.path.join(orig_path,raw_folder,speaker,filename2), sr=16000)   
    for i in range(num_of_speakers):
        wav.append(wav_data)
for datafile,i in zip(b,range(len(wav))):
    np.savetxt(os.path.normpath(os.path.join(orig_path,log_folder,filename,str(datafile.replace('.wav','.txt')))), wav[i], delimiter=',')

# %%
b
# Out:
# ['mixed_bbaf3p_lwiy6n.wav',
#  'mixed_bbaf3p_pwag6n.wav',
#  'mixed_bbaf4a_lwiy6n.wav',
#  'mixed_bbaf4a_pwag6n.wav',
#  'mixed_bbal5n_lwiy6n.wav',
#  'mixed_bbal5n_pwag6n.wav',
#  'mixed_bbal6s_lwiy6n.wav',
#  'mixed_bbal6s_pwag6n.wav',
#  'mixed_bbas2a_lwiy6n.wav',
#  'mixed_bbas2a_pwag6n.wav',
#  'mixed_bbaszs_lwiy6n.wav',
#  'mixed_bbaszs_pwag6n.wav',
#  'mixed_bbaz5p_lwiy6n.wav',
#  'mixed_bbaz5p_pwag6n.wav',
#  'mixed_bbaz6a_lwiy6n.wav',
#  'mixed_bbaz6a_pwag6n.wav',
#  'mixed_bbbf5n_lwiy6n.wav',
#  'mixed_bbbf5n_pwag6n.wav',
#  'mixed_bbbl9n_lwiy6n.wav',
#  'mixed_bbbl9n_pwag6n.wav',
#  'mixed_bbbm1p_lwiy6n.wav',
#  'mixed_bbbm1p_pwag6n.wav',
#  'mixed_bbbmzs_lwiy6n.wav',
#  'mixed_bbbmzs_pwag6n.wav',
#  'mixed_bbbs4s_lwiy6n.wav',
#  'mixed_bbbs4s_pwag6n.wav',
#  'mixed_bbbs6a_lwiy6n.wav',
#  'mixed_bbbs6a_pwag6n.wav',
#  'mixed_bbbz7n_lwiy6n.wav',
#  'mixed_bbbz7n_pwag6n.wav',
#  'mixed_bbbz8s_lwiy6n.wav',
#  'mixed_bbbz8s_pwag6n.wav',
#  'mixed_bbbz9p_lwiy6n.wav',
#  'mixed_bbbz9p_pwag6n.wav',
#  'mixed_bbie7n_lwiy6n.wav',
#  'mixed_bbie7n_pwag6n.wav',
#  'mixed_bbie8s_lwiy6n.wav',
#  'mixed_bbie8s_pwag6n.wav',
#  'mixed_bbil1n_lwiy6n.wav',
#  'mixed_bbil1n_pwag6n.wav',
#  'mixed_bbil3p_lwiy6n.wav',
#  'mixed_bbil3p_pwag6n.wav',
#  'mixed_bbil4a_lwiy6n.wav',
#  'mixed_bbil4a_pwag6n.wav',
#  'mixed_bbir7p_lwiy6n.wav',
#  'mixed_bbir7p_pwag6n.wav',
#  'mixed_bbir8a_lwiy6n.wav',
#  'mixed_bbir8a_pwag6n.wav',
#  'mixed_bbiy9n_lwiy6n.wav',
#  'mixed_bbiy9n_pwag6n.wav',
#  'mixed_bbiz1p_lwiy6n.wav',
#  'mixed_bbiz1p_pwag6n.wav',
#  'mixed_bbiz2a_lwiy6n.wav',
#  'mixed_bbiz2a_pwag6n.wav',
#  'mixed_bbwf9n_lwiy6n.wav',
#  'mixed_bbwf9n_pwag6n.wav',
#  'mixed_bbwg1p_lwiy6n.wav',
#  'mixed_bbwg1p_pwag6n.wav',
#  'mixed_bbwg2a_lwiy6n.wav',
#  'mixed_bbwg2a_pwag6n.wav',
#  'mixed_bbwgzs_lwiy6n.wav',
#  'mixed_bbwgzs_pwag6n.wav',
#  'mixed_bbwm4s_lwiy6n.wav',
#  'mixed_bbwm4s_pwag6n.wav',
#  'mixed_bbwm6a_lwiy6n.wav',
#  'mixed_bbwm6a_pwag6n.wav',
#  'mixed_bbwtza_lwiy6n.wav',
#  'mixed_bbwtza_pwag6n.wav',
#  'mixed_bgaa5n_lwiy6n.wav',
#  'mixed_bgaa5n_pwag6n.wav',
#  'mixed_bgaa6s_lwiy6n.wav',
#  'mixed_bgaa6s_pwag6n.wav',
#  'mixed_bgag9n_lwiy6n.wav',
#  'mixed_bgag9n_pwag6n.wav',
#  'mixed_bgah1p_lwiy6n.wav',
#  'mixed_bgah1p_pwag6n.wav',
#  'mixed_bgah2a_lwiy6n.wav',
#  'mixed_bgah2a_pwag6n.wav',
#  'mixed_bgan3n_lwiy6n.wav',
#  'mixed_bgan3n_pwag6n.wav',
#  'mixed_bgan6a_lwiy6n.wav',
#  'mixed_bgan6a_pwag6n.wav',
#  'mixed_bgat8s_lwiy6n.wav',
#  'mixed_bgat8s_pwag6n.wav',
#  'mixed_bgat9p_lwiy6n.wav',
#  'mixed_bgat9p_pwag6n.wav',
#  'mixed_bgbb1p_lwiy6n.wav',
#  'mixed_bgbb1p_pwag6n.wav',
#  'mixed_bgbh4s_lwiy6n.wav',
#  'mixed_bgbh4s_pwag6n.wav',
#  'mixed_bgbh6a_lwiy6n.wav',
#  'mixed_bgbh6a_pwag6n.wav',
#  'mixed_bgbn8s_lwiy6n.wav',
#  'mixed_bgbn8s_pwag6n.wav',
#  'mixed_bgbu1n_lwiy6n.wav',
#  'mixed_bgbu1n_pwag6n.wav',
#  'mixed_bgbu2s_lwiy6n.wav',
#  'mixed_bgbu2s_pwag6n.wav',
#  'mixed_bgia3p_lwiy6n.wav',
#  'mixed_bgia3p_pwag6n.wav',
#  'mixed_bgia4a_lwiy6n.wav',
#  'mixed_bgia4a_pwag6n.wav',
#  'mixed_bgig5n_lwiy6n.wav',
#  'mixed_bgig5n_pwag6n.wav',
#  'mixed_bgig7p_lwiy6n.wav',
#  'mixed_bgig7p_pwag6n.wav',
#  'mixed_bgig8a_lwiy6n.wav',
#  'mixed_bgig8a_pwag6n.wav',
#  'mixed_bgim9n_lwiy6n.wav',
#  'mixed_bgim9n_pwag6n.wav',
#  'mixed_bgin1p_lwiy6n.wav',
#  'mixed_bgin1p_pwag6n.wav',
#  'mixed_bgin2a_lwiy6n.wav',
#  'mixed_bgin2a_pwag6n.wav',
#  'mixed_bgit4s_lwiy6n.wav',
#  'mixed_bgit4s_pwag6n.wav',
#  'mixed_bgit5p_lwiy6n.wav',
#  'mixed_bgit5p_pwag6n.wav',
#  'mixed_bgit6a_lwiy6n.wav',
#  'mixed_bgit6a_pwag6n.wav',
#  'mixed_bgwb3n_lwiy6n.wav',
#  'mixed_bgwb3n_pwag6n.wav',
#  'mixed_bgwb6a_lwiy6n.wav',
#  'mixed_bgwb6a_pwag6n.wav',
#  'mixed_bgwh8s_lwiy6n.wav',
#  'mixed_bgwh8s_pwag6n.wav',
#  'mixed_bgwh9p_lwiy6n.wav',
#  'mixed_bgwh9p_pwag6n.wav',
#  'mixed_bgwiza_lwiy6n.wav',
#  'mixed_bgwiza_pwag6n.wav',
#  'mixed_bgwo1n_lwiy6n.wav',
#  'mixed_bgwo1n_pwag6n.wav',
#  'mixed_bgwo2s_lwiy6n.wav',
#  'mixed_bgwo2s_pwag6n.wav',
#  'mixed_bgwo4a_lwiy6n.wav',
#  'mixed_bgwo4a_pwag6n.wav',
#  'mixed_bgwu5n_lwiy6n.wav',
#  'mixed_bgwu5n_pwag6n.wav',
#  'mixed_bgwu8a_lwiy6n.wav',
#  'mixed_bgwu8a_pwag6n.wav',
#  'mixed_braf7n_lwiy6n.wav',
#  'mixed_braf7n_pwag6n.wav',
#  'mixed_braf8s_lwiy6n.wav',
#  'mixed_braf8s_pwag6n.wav',
#  'mixed_braf9p_lwiy6n.wav',
#  'mixed_braf9p_pwag6n.wav',
#  'mixed_bragza_lwiy6n.wav',
#  'mixed_bragza_pwag6n.wav',
#  'mixed_bram1n_lwiy6n.wav',
#  'mixed_bram1n_pwag6n.wav',
#  'mixed_bram3p_lwiy6n.wav',
#  'mixed_bram3p_pwag6n.wav',
#  'mixed_bras5n_lwiy6n.wav',
#  'mixed_bras5n_pwag6n.wav',
#  'mixed_bras6s_lwiy6n.wav',
#  'mixed_bras6s_pwag6n.wav',
#  'mixed_brbaza_lwiy6n.wav',
#  'mixed_brbaza_pwag6n.wav',
#  'mixed_brbg1n_lwiy6n.wav',
#  'mixed_brbg1n_pwag6n.wav',
#  'mixed_brbg2s_lwiy6n.wav',
#  'mixed_brbg2s_pwag6n.wav',
#  'mixed_brbg4a_lwiy6n.wav',
#  'mixed_brbg4a_pwag6n.wav',
#  'mixed_brbm7p_lwiy6n.wav',
#  'mixed_brbm7p_pwag6n.wav',
#  'mixed_brbs9n_lwiy6n.wav',
#  'mixed_brbs9n_pwag6n.wav',
#  'mixed_brif3n_lwiy6n.wav',
#  'mixed_brif3n_pwag6n.wav',
#  'mixed_bril8s_lwiy6n.wav',
#  'mixed_bril8s_pwag6n.wav',
#  'mixed_bris1n_lwiy6n.wav',
#  'mixed_bris1n_pwag6n.wav',
#  'mixed_bris2s_lwiy6n.wav',
#  'mixed_bris2s_pwag6n.wav',
#  'mixed_bris3p_lwiy6n.wav',
#  'mixed_bris3p_pwag6n.wav',
#  'mixed_briz5n_lwiy6n.wav',
#  'mixed_briz5n_pwag6n.wav',
#  'mixed_briz6s_lwiy6n.wav',
#  'mixed_briz6s_pwag6n.wav',
#  'mixed_brwa2s_lwiy6n.wav',
#  'mixed_brwa2s_pwag6n.wav',
#  'mixed_brwg6s_lwiy6n.wav',
#  'mixed_brwg6s_pwag6n.wav',
#  'mixed_brwm9n_lwiy6n.wav',
#  'mixed_brwm9n_pwag6n.wav',
#  'mixed_brwn1p_lwiy6n.wav',
#  'mixed_brwn1p_pwag6n.wav',
#  'mixed_brwn2a_lwiy6n.wav',
#  'mixed_brwn2a_pwag6n.wav',
#  'mixed_brwt6a_lwiy6n.wav',
#  'mixed_brwt6a_pwag6n.wav',
#  'mixed_bwaa1p_lwiy6n.wav',
#  'mixed_bwaa1p_pwag6n.wav',
#  'mixed_bwaa2a_lwiy6n.wav',
#  'mixed_bwaa2a_pwag6n.wav',
#  'mixed_bwaazs_lwiy6n.wav',
#  'mixed_bwaazs_pwag6n.wav',
#  'mixed_bwag3n_lwiy6n.wav',
#  'mixed_bwag3n_pwag6n.wav',
#  'mixed_bwag5p_lwiy6n.wav',
#  'mixed_bwag5p_pwag6n.wav',
#  'mixed_bwag6a_lwiy6n.wav',
#  'mixed_bwag6a_pwag6n.wav',
#  'mixed_bwam9p_lwiy6n.wav',
#  'mixed_bwam9p_pwag6n.wav',
#  'mixed_bwanza_lwiy6n.wav',
#  'mixed_bwanza_pwag6n.wav',
#  'mixed_bwat3p_lwiy6n.wav',
#  'mixed_bwat3p_pwag6n.wav',
#  'mixed_bwat4a_lwiy6n.wav',
#  'mixed_bwat4a_pwag6n.wav',
#  'mixed_bwbg7n_lwiy6n.wav',
#  'mixed_bwbg7n_pwag6n.wav',
#  'mixed_bwbg8s_lwiy6n.wav',
#  'mixed_bwbg8s_pwag6n.wav',
#  'mixed_bwbhza_lwiy6n.wav',
#  'mixed_bwbhza_pwag6n.wav',
#  'mixed_bwbn3p_lwiy6n.wav',
#  'mixed_bwbn3p_pwag6n.wav',
#  'mixed_bwbt6s_lwiy6n.wav',
#  'mixed_bwbt6s_pwag6n.wav',
#  'mixed_bwbt7p_lwiy6n.wav',
#  'mixed_bwbt7p_pwag6n.wav',
#  'mixed_bwbt8a_lwiy6n.wav',
#  'mixed_bwbt8a_pwag6n.wav',
#  'mixed_bwig1p_lwiy6n.wav',
#  'mixed_bwig1p_pwag6n.wav',
#  'mixed_bwig2a_lwiy6n.wav',
#  'mixed_bwig2a_pwag6n.wav',
#  'mixed_bwim5p_lwiy6n.wav',
#  'mixed_bwim5p_pwag6n.wav',
#  'mixed_bwim6a_lwiy6n.wav',
#  'mixed_bwim6a_pwag6n.wav',
#  'mixed_bwis7n_lwiy6n.wav',
#  'mixed_bwis7n_pwag6n.wav',
#  'mixed_bwis8s_lwiy6n.wav',
#  'mixed_bwis8s_pwag6n.wav',
#  'mixed_bwis9p_lwiy6n.wav',
#  'mixed_bwis9p_pwag6n.wav',
#  'mixed_bwitza_lwiy6n.wav',
#  'mixed_bwitza_pwag6n.wav',
#  'mixed_bwwbza_lwiy6n.wav',
#  'mixed_bwwbza_pwag6n.wav',
#  'mixed_bwwh2s_lwiy6n.wav',
#  'mixed_bwwh2s_pwag6n.wav',
#  'mixed_bwwh3p_lwiy6n.wav',
#  'mixed_bwwh3p_pwag6n.wav',
#  'mixed_bwwn5n_lwiy6n.wav',
#  'mixed_bwwn5n_pwag6n.wav',
#  'mixed_bwwn7p_lwiy6n.wav',
#  'mixed_bwwn7p_pwag6n.wav',
#  'mixed_bwwt9n_lwiy6n.wav',
#  'mixed_bwwt9n_pwag6n.wav',
#  'mixed_bwwu1p_lwiy6n.wav',
#  'mixed_bwwu1p_pwag6n.wav',
#  'mixed_bwwu2a_lwiy6n.wav',
#  'mixed_bwwu2a_pwag6n.wav',
#  'mixed_bwwuzs_lwiy6n.wav',
#  'mixed_bwwuzs_pwag6n.wav',
#  'mixed_lbad5n_lwiy6n.wav',
#  'mixed_lbad5n_pwag6n.wav',
#  'mixed_lbaj9n_lwiy6n.wav',
#  'mixed_lbaj9n_pwag6n.wav',
#  'mixed_lbak1p_lwiy6n.wav',
#  'mixed_lbak1p_pwag6n.wav',
#  'mixed_lbakzs_lwiy6n.wav',
#  'mixed_lbakzs_pwag6n.wav',
#  'mixed_lbaq3n_lwiy6n.wav',
#  'mixed_lbaq3n_pwag6n.wav',
#  'mixed_lbaq5p_lwiy6n.wav',
#  'mixed_lbaq5p_pwag6n.wav',
#  'mixed_lbaq6a_lwiy6n.wav',
#  'mixed_lbaq6a_pwag6n.wav',
#  'mixed_lbax9p_lwiy6n.wav',
#  'mixed_lbax9p_pwag6n.wav',
#  'mixed_lbayza_lwiy6n.wav',
#  'mixed_lbayza_pwag6n.wav',
#  'mixed_lbbd9n_lwiy6n.wav',
#  'mixed_lbbd9n_pwag6n.wav',
#  'mixed_lbbe1p_lwiy6n.wav',
#  'mixed_lbbe1p_pwag6n.wav',
#  'mixed_lbbe2a_lwiy6n.wav',
#  'mixed_lbbe2a_pwag6n.wav',
#  'mixed_lbbezs_lwiy6n.wav',
#  'mixed_lbbezs_pwag6n.wav',
#  'mixed_lbbk3n_lwiy6n.wav',
#  'mixed_lbbk3n_pwag6n.wav',
#  'mixed_lbbq8s_lwiy6n.wav',
#  'mixed_lbbq8s_pwag6n.wav',
#  'mixed_lbbq9p_lwiy6n.wav',
#  'mixed_lbbq9p_pwag6n.wav',
#  'mixed_lbid1n_lwiy6n.wav',
#  'mixed_lbid1n_pwag6n.wav',
#  'mixed_lbid3p_lwiy6n.wav',
#  'mixed_lbid3p_pwag6n.wav',
#  'mixed_lbij6s_lwiy6n.wav',
#  'mixed_lbij6s_pwag6n.wav',
#  'mixed_lbiq1p_lwiy6n.wav',
#  'mixed_lbiq1p_pwag6n.wav',
#  'mixed_lbix4s_lwiy6n.wav',
#  'mixed_lbix4s_pwag6n.wav',
#  'mixed_lbix5p_lwiy6n.wav',
#  'mixed_lbix5p_pwag6n.wav',
#  'mixed_lbix6a_lwiy6n.wav',
#  'mixed_lbix6a_pwag6n.wav',
#  'mixed_lbwe5p_lwiy6n.wav',
#  'mixed_lbwe5p_pwag6n.wav',
#  'mixed_lbwe6a_lwiy6n.wav',
#  'mixed_lbwe6a_pwag6n.wav',
#  'mixed_lbwk7n_lwiy6n.wav',
#  'mixed_lbwk7n_pwag6n.wav',
#  'mixed_lbwk8s_lwiy6n.wav',
#  'mixed_lbwk8s_pwag6n.wav',
#  'mixed_lbwlza_lwiy6n.wav',
#  'mixed_lbwlza_pwag6n.wav',
#  'mixed_lbwr1n_lwiy6n.wav',
#  'mixed_lbwr1n_pwag6n.wav',
#  'mixed_lbwr3p_lwiy6n.wav',
#  'mixed_lbwr3p_pwag6n.wav',
#  'mixed_lbwr4a_lwiy6n.wav',
#  'mixed_lbwr4a_pwag6n.wav',
#  'mixed_lbwy5n_lwiy6n.wav',
#  'mixed_lbwy5n_pwag6n.wav',
#  'mixed_lbwy6s_lwiy6n.wav',
#  'mixed_lbwy6s_pwag6n.wav',
#  'mixed_lbwy7p_lwiy6n.wav',
#  'mixed_lbwy7p_pwag6n.wav',
#  'mixed_lgaf3n_lwiy6n.wav',
#  'mixed_lgaf3n_pwag6n.wav',
#  'mixed_lgaf4s_lwiy6n.wav',
#  'mixed_lgaf4s_pwag6n.wav',
#  'mixed_lgaf6a_lwiy6n.wav',
#  'mixed_lgaf6a_pwag6n.wav',
#  'mixed_lgal8s_lwiy6n.wav',
#  'mixed_lgal8s_pwag6n.wav',
#  'mixed_lgal9p_lwiy6n.wav',
#  'mixed_lgal9p_pwag6n.wav',
#  'mixed_lgamza_lwiy6n.wav',
#  'mixed_lgamza_pwag6n.wav',
#  'mixed_lgas2s_lwiy6n.wav',
#  'mixed_lgas2s_pwag6n.wav',
#  'mixed_lgaz5n_lwiy6n.wav',
#  'mixed_lgaz5n_pwag6n.wav',
#  'mixed_lgaz6s_lwiy6n.wav',
#  'mixed_lgaz6s_pwag6n.wav',
#  'mixed_lgaz7p_lwiy6n.wav',
#  'mixed_lgaz7p_pwag6n.wav',
#  'mixed_lgbf8s_lwiy6n.wav',
#  'mixed_lgbf8s_pwag6n.wav',
#  'mixed_lgbf9p_lwiy6n.wav',
#  'mixed_lgbf9p_pwag6n.wav',
#  'mixed_lgbgza_lwiy6n.wav',
#  'mixed_lgbgza_pwag6n.wav',
#  'mixed_lgbm1n_lwiy6n.wav',
#  'mixed_lgbm1n_pwag6n.wav',
#  'mixed_lgbm2s_lwiy6n.wav',
#  'mixed_lgbm2s_pwag6n.wav',
#  'mixed_lgbm3p_lwiy6n.wav',
#  'mixed_lgbm3p_pwag6n.wav',
#  'mixed_lgbz9n_lwiy6n.wav',
#  'mixed_lgbz9n_pwag6n.wav',
#  'mixed_lgif2a_lwiy6n.wav',
#  'mixed_lgif2a_pwag6n.wav',
#  'mixed_lgil3n_lwiy6n.wav',
#  'mixed_lgil3n_pwag6n.wav',
#  'mixed_lgil4s_lwiy6n.wav',
#  'mixed_lgil4s_pwag6n.wav',
#  'mixed_lgil6a_lwiy6n.wav',
#  'mixed_lgil6a_pwag6n.wav',
#  'mixed_lgir7n_lwiy6n.wav',
#  'mixed_lgir7n_pwag6n.wav',
#  'mixed_lgir9p_lwiy6n.wav',
#  'mixed_lgir9p_pwag6n.wav',
#  'mixed_lgisza_lwiy6n.wav',
#  'mixed_lgisza_pwag6n.wav',
#  'mixed_lgiz1n_lwiy6n.wav',
#  'mixed_lgiz1n_pwag6n.wav',
#  'mixed_lgiz2s_lwiy6n.wav',
#  'mixed_lgiz2s_pwag6n.wav',
#  'mixed_lgwg2s_lwiy6n.wav',
#  'mixed_lgwg2s_pwag6n.wav',
#  'mixed_lgwg3p_lwiy6n.wav',
#  'mixed_lgwg3p_pwag6n.wav',
#  'mixed_lgwm5n_lwiy6n.wav',
#  'mixed_lgwm5n_pwag6n.wav',
#  'mixed_lgwm7p_lwiy6n.wav',
#  'mixed_lgwm7p_pwag6n.wav',
#  'mixed_lgwm8a_lwiy6n.wav',
#  'mixed_lgwm8a_pwag6n.wav',
#  'mixed_lgws9n_lwiy6n.wav',
#  'mixed_lgws9n_pwag6n.wav',
#  'mixed_lgwt1p_lwiy6n.wav',
#  'mixed_lgwt1p_pwag6n.wav',
#  'mixed_lgwt2a_lwiy6n.wav',
#  'mixed_lgwt2a_pwag6n.wav',
#  'mixed_lrae2s_lwiy6n.wav',
#  'mixed_lrae2s_pwag6n.wav',
#  'mixed_lrak6s_lwiy6n.wav',
#  'mixed_lrak6s_pwag6n.wav',
#  'mixed_lrak7p_lwiy6n.wav',
#  'mixed_lrak7p_pwag6n.wav',
#  'mixed_lrak8a_lwiy6n.wav',
#  'mixed_lrak8a_pwag6n.wav',
#  'mixed_lrar1p_lwiy6n.wav',
#  'mixed_lrar1p_pwag6n.wav',
#  'mixed_lray5p_lwiy6n.wav',
#  'mixed_lray5p_pwag6n.wav',
#  'mixed_lrbe5n_lwiy6n.wav',
#  'mixed_lrbe5n_pwag6n.wav',
#  'mixed_lrbe6s_lwiy6n.wav',
#  'mixed_lrbe6s_pwag6n.wav',
#  'mixed_lrbe7p_lwiy6n.wav',
#  'mixed_lrbe7p_pwag6n.wav',
#  'mixed_lrbk9n_lwiy6n.wav',
#  'mixed_lrbk9n_pwag6n.wav',
#  'mixed_lrbr5p_lwiy6n.wav',
#  'mixed_lrbr5p_pwag6n.wav',
#  'mixed_lrbr6a_lwiy6n.wav',
#  'mixed_lrbr6a_pwag6n.wav',
#  'mixed_lrby8s_lwiy6n.wav',
#  'mixed_lrby8s_pwag6n.wav',
#  'mixed_lrbzza_lwiy6n.wav',
#  'mixed_lrbzza_pwag6n.wav',
#  'mixed_lrid9p_lwiy6n.wav',
#  'mixed_lrid9p_pwag6n.wav',
#  'mixed_lrik3p_lwiy6n.wav',
#  'mixed_lrik3p_pwag6n.wav',
#  'mixed_lrik4a_lwiy6n.wav',
#  'mixed_lrik4a_pwag6n.wav',
#  'mixed_lriq5n_lwiy6n.wav',
#  'mixed_lriq5n_pwag6n.wav',
#  'mixed_lriq6s_lwiy6n.wav',
#  'mixed_lriq6s_pwag6n.wav',
#  'mixed_lriy1p_lwiy6n.wav',
#  'mixed_lriy1p_pwag6n.wav',
#  'mixed_lriy2a_lwiy6n.wav',
#  'mixed_lriy2a_pwag6n.wav',
#  'mixed_lrwf1p_lwiy6n.wav',
#  'mixed_lrwf1p_pwag6n.wav',
#  'mixed_lrwl3n_lwiy6n.wav',
#  'mixed_lrwl3n_pwag6n.wav',
#  'mixed_lrwr7n_lwiy6n.wav',
#  'mixed_lrwr7n_pwag6n.wav',
#  'mixed_lrwr9p_lwiy6n.wav',
#  'mixed_lrwr9p_pwag6n.wav',
#  'mixed_lrwz4a_lwiy6n.wav',
#  'mixed_lrwz4a_pwag6n.wav',
#  'mixed_lwae7n_lwiy6n.wav',
#  'mixed_lwae7n_pwag6n.wav',
#  'mixed_lwae8s_lwiy6n.wav',
#  'mixed_lwae8s_pwag6n.wav',
#  'mixed_lwae9p_lwiy6n.wav',
#  'mixed_lwae9p_pwag6n.wav',
#  'mixed_lwal1n_lwiy6n.wav',
#  'mixed_lwal1n_pwag6n.wav',
#  'mixed_lwal4a_lwiy6n.wav',
#  'mixed_lwal4a_pwag6n.wav',
#  'mixed_lwar5n_lwiy6n.wav',
#  'mixed_lwar5n_pwag6n.wav',
#  'mixed_lwar7p_lwiy6n.wav',
#  'mixed_lwar7p_pwag6n.wav',
#  'mixed_lway9n_lwiy6n.wav',
#  'mixed_lway9n_pwag6n.wav',
#  'mixed_lwaz1p_lwiy6n.wav',
#  'mixed_lwaz1p_pwag6n.wav',
#  'mixed_lwazzs_lwiy6n.wav',
#  'mixed_lwazzs_pwag6n.wav',
#  'mixed_lwbl6s_lwiy6n.wav',
#  'mixed_lwbl6s_pwag6n.wav',
#  'mixed_lwbl7p_lwiy6n.wav',
#  'mixed_lwbl7p_pwag6n.wav',
#  'mixed_lwbr9n_lwiy6n.wav',
#  'mixed_lwbr9n_pwag6n.wav',
#  'mixed_lwbs1p_lwiy6n.wav',
#  'mixed_lwbs1p_pwag6n.wav',
#  'mixed_lwbs2a_lwiy6n.wav',
#  'mixed_lwbs2a_pwag6n.wav',
#  'mixed_lwbz3n_lwiy6n.wav',
#  'mixed_lwbz3n_pwag6n.wav',
#  'mixed_lwbz5p_lwiy6n.wav',
#  'mixed_lwbz5p_pwag6n.wav',
#  'mixed_lwbz6a_lwiy6n.wav',
#  'mixed_lwbz6a_pwag6n.wav',
#  'mixed_lwie3n_lwiy6n.wav',
#  'mixed_lwie3n_pwag6n.wav',
#  'mixed_lwie5p_lwiy6n.wav',
#  'mixed_lwie5p_pwag6n.wav',
#  'mixed_lwie6a_lwiy6n.wav',
#  'mixed_lwie6a_pwag6n.wav',
#  'mixed_lwik8s_lwiy6n.wav',
#  'mixed_lwik8s_pwag6n.wav',
#  'mixed_lwir2s_lwiy6n.wav',
#  'mixed_lwir2s_pwag6n.wav',
#  'mixed_lwir3p_lwiy6n.wav',
#  'mixed_lwir3p_pwag6n.wav',
#  'mixed_lwiy5n_lwiy6n.wav',
#  'mixed_lwiy5n_pwag6n.wav',
#  'mixed_lwiy7p_lwiy6n.wav',
#  'mixed_lwiy7p_pwag6n.wav',
#  'mixed_lwiy8a_lwiy6n.wav',
#  'mixed_lwiy8a_pwag6n.wav',
#  'mixed_lwwf5n_lwiy6n.wav',
#  'mixed_lwwf5n_pwag6n.wav',
#  'mixed_lwwf7p_lwiy6n.wav',
#  'mixed_lwwf7p_pwag6n.wav',
#  'mixed_lwwl9n_lwiy6n.wav',
#  'mixed_lwwl9n_pwag6n.wav',
#  'mixed_lwwm2a_lwiy6n.wav',
#  'mixed_lwwm2a_pwag6n.wav',
#  'mixed_lwws5p_lwiy6n.wav',
#  'mixed_lwws5p_pwag6n.wav',
#  'mixed_lwws6a_lwiy6n.wav',
#  'mixed_lwws6a_pwag6n.wav',
#  'mixed_lwwz7n_lwiy6n.wav',
#  'mixed_lwwz7n_pwag6n.wav',
#  'mixed_pbab9n_lwiy6n.wav',
#  'mixed_pbab9n_pwag6n.wav',
#  'mixed_pbac1p_lwiy6n.wav',
#  'mixed_pbac1p_pwag6n.wav',
#  'mixed_pbaczs_lwiy6n.wav',
#  'mixed_pbaczs_pwag6n.wav',
#  'mixed_pbai6a_lwiy6n.wav',
#  'mixed_pbai6a_pwag6n.wav',
#  'mixed_pbao8s_lwiy6n.wav',
#  'mixed_pbao8s_pwag6n.wav',
#  'mixed_pbao9p_lwiy6n.wav',
#  'mixed_pbao9p_pwag6n.wav',
#  'mixed_pbav1n_lwiy6n.wav',
#  'mixed_pbav1n_pwag6n.wav',
#  'mixed_pbav2s_lwiy6n.wav',
#  'mixed_pbav2s_pwag6n.wav',
#  'mixed_pbbc3n_lwiy6n.wav',
#  'mixed_pbbc3n_pwag6n.wav',
#  'mixed_pbbc5p_lwiy6n.wav',
#  'mixed_pbbc5p_pwag6n.wav',
#  'mixed_pbbi7n_lwiy6n.wav',
#  'mixed_pbbi7n_pwag6n.wav',
#  'mixed_pbbi9p_lwiy6n.wav',
#  'mixed_pbbi9p_pwag6n.wav',
#  'mixed_pbbjza_lwiy6n.wav',
#  'mixed_pbbjza_pwag6n.wav',
#  'mixed_pbbp2s_lwiy6n.wav',
#  'mixed_pbbp2s_pwag6n.wav',
#  'mixed_pbbp3p_lwiy6n.wav',
#  'mixed_pbbp3p_pwag6n.wav',
#  'mixed_pbbv5n_lwiy6n.wav',
#  'mixed_pbbv5n_pwag6n.wav',
#  'mixed_pbbv8a_lwiy6n.wav',
#  'mixed_pbbv8a_pwag6n.wav',
#  'mixed_pbib6s_lwiy6n.wav',
#  'mixed_pbib6s_pwag6n.wav',
#  'mixed_pbib7p_lwiy6n.wav',
#  'mixed_pbib7p_pwag6n.wav',
#  'mixed_pbib8a_lwiy6n.wav',
#  'mixed_pbib8a_pwag6n.wav',
#  'mixed_pbih9n_lwiy6n.wav',
#  'mixed_pbih9n_pwag6n.wav',
#  'mixed_pbio3n_lwiy6n.wav',
#  'mixed_pbio3n_pwag6n.wav',
#  'mixed_pbio4s_lwiy6n.wav',
#  'mixed_pbio4s_pwag6n.wav',
#  'mixed_pbio5p_lwiy6n.wav',
#  'mixed_pbio5p_pwag6n.wav',
#  'mixed_pbiu9p_lwiy6n.wav',
#  'mixed_pbiu9p_pwag6n.wav',
#  'mixed_pbivza_lwiy6n.wav',
#  'mixed_pbivza_pwag6n.wav',
#  'mixed_pbwc9p_lwiy6n.wav',
#  'mixed_pbwc9p_pwag6n.wav',
#  'mixed_pbwj2s_lwiy6n.wav',
#  'mixed_pbwj2s_pwag6n.wav',
#  'mixed_pbwj4a_lwiy6n.wav',
#  'mixed_pbwj4a_pwag6n.wav',
#  'mixed_pbwp7p_lwiy6n.wav',
#  'mixed_pbwp7p_pwag6n.wav',
#  'mixed_pbwv9n_lwiy6n.wav',
#  'mixed_pbwv9n_pwag6n.wav',
#  'mixed_pbwxzs_lwiy6n.wav',
#  'mixed_pbwxzs_pwag6n.wav',
#  'mixed_pgad8s_lwiy6n.wav',
#  'mixed_pgad8s_pwag6n.wav',
#  'mixed_pgaeza_lwiy6n.wav',
#  'mixed_pgaeza_pwag6n.wav',
#  'mixed_pgak3p_lwiy6n.wav',
#  'mixed_pgak3p_pwag6n.wav',
#  'mixed_pgaq6s_lwiy6n.wav',
#  'mixed_pgaq6s_pwag6n.wav',
#  'mixed_pgax9n_lwiy6n.wav',
#  'mixed_pgax9n_pwag6n.wav',
#  'mixed_pgay1p_lwiy6n.wav',
#  'mixed_pgay1p_pwag6n.wav',
#  'mixed_pgay2a_lwiy6n.wav',
#  'mixed_pgay2a_pwag6n.wav',
#  'mixed_pgbe2s_lwiy6n.wav',
#  'mixed_pgbe2s_pwag6n.wav',
#  'mixed_pgbe3p_lwiy6n.wav',
#  'mixed_pgbe3p_pwag6n.wav',
#  'mixed_pgbe4a_lwiy6n.wav',
#  'mixed_pgbe4a_pwag6n.wav',
#  'mixed_pgbk6s_lwiy6n.wav',
#  'mixed_pgbk6s_pwag6n.wav',
#  'mixed_pgbk8a_lwiy6n.wav',
#  'mixed_pgbk8a_pwag6n.wav',
#  'mixed_pgbr1p_lwiy6n.wav',
#  'mixed_pgbr1p_pwag6n.wav',
#  'mixed_pgbrzs_lwiy6n.wav',
#  'mixed_pgbrzs_pwag6n.wav',
#  'mixed_pgby3n_lwiy6n.wav',
#  'mixed_pgby3n_pwag6n.wav',
#  'mixed_pgby4s_lwiy6n.wav',
#  'mixed_pgby4s_pwag6n.wav',
#  'mixed_pgby6a_lwiy6n.wav',
#  'mixed_pgby6a_pwag6n.wav',
#  'mixed_pgiq1n_lwiy6n.wav',
#  'mixed_pgiq1n_pwag6n.wav',
#  'mixed_pgiq2s_lwiy6n.wav',
#  'mixed_pgiq2s_pwag6n.wav',
#  'mixed_pgix8a_lwiy6n.wav',
#  'mixed_pgix8a_pwag6n.wav',
#  'mixed_pgwe7p_lwiy6n.wav',
#  'mixed_pgwe7p_pwag6n.wav',
#  'mixed_pgwl1p_lwiy6n.wav',
#  'mixed_pgwl1p_pwag6n.wav',
#  'mixed_pgwr4s_lwiy6n.wav',
#  'mixed_pgwr4s_pwag6n.wav',
#  'mixed_pgwr6a_lwiy6n.wav',
#  'mixed_pgwr6a_pwag6n.wav',
#  'mixed_praj1p_lwiy6n.wav',
#  'mixed_praj1p_pwag6n.wav',
#  'mixed_prap3n_lwiy6n.wav',
#  'mixed_prap3n_pwag6n.wav',
#  'mixed_prap5p_lwiy6n.wav',
#  'mixed_prap5p_pwag6n.wav',
#  'mixed_prap6a_lwiy6n.wav',
#  'mixed_prap6a_pwag6n.wav',
#  'mixed_prav7n_lwiy6n.wav',
#  'mixed_prav7n_pwag6n.wav',
#  'mixed_prav8s_lwiy6n.wav',
#  'mixed_prav8s_pwag6n.wav',
#  'mixed_prav9p_lwiy6n.wav',
#  'mixed_prav9p_pwag6n.wav',
#  'mixed_prbc9n_lwiy6n.wav',
#  'mixed_prbc9n_pwag6n.wav',
#  'mixed_prbd1p_lwiy6n.wav',
#  'mixed_prbd1p_pwag6n.wav',
#  'mixed_prbd2a_lwiy6n.wav',
#  'mixed_prbd2a_pwag6n.wav',
#  'mixed_prbdzs_lwiy6n.wav',
#  'mixed_prbdzs_pwag6n.wav',
#  'mixed_prbj3n_lwiy6n.wav',
#  'mixed_prbj3n_pwag6n.wav',
#  'mixed_prbj6a_lwiy6n.wav',
#  'mixed_prbj6a_pwag6n.wav',
#  'mixed_prbp7n_lwiy6n.wav',
#  'mixed_prbp7n_pwag6n.wav',
#  'mixed_prbp9p_lwiy6n.wav',
#  'mixed_prbp9p_pwag6n.wav',
#  'mixed_prbx1n_lwiy6n.wav',
#  'mixed_prbx1n_pwag6n.wav',
#  'mixed_pric2s_lwiy6n.wav',
#  'mixed_pric2s_pwag6n.wav',
#  'mixed_pric3p_lwiy6n.wav',
#  'mixed_pric3p_pwag6n.wav',
#  'mixed_prii5n_lwiy6n.wav',
#  'mixed_prii5n_pwag6n.wav',
#  'mixed_prii6s_lwiy6n.wav',
#  'mixed_prii6s_pwag6n.wav',
#  'mixed_prii7p_lwiy6n.wav',
#  'mixed_prii7p_pwag6n.wav',
#  'mixed_prio9n_lwiy6n.wav',
#  'mixed_prio9n_pwag6n.wav',
#  'mixed_prip1p_lwiy6n.wav',
#  'mixed_prip1p_pwag6n.wav',
#  'mixed_priv3n_lwiy6n.wav',
#  'mixed_priv3n_pwag6n.wav',
#  'mixed_priv4s_lwiy6n.wav',
#  'mixed_priv4s_pwag6n.wav',
#  'mixed_prwd5p_lwiy6n.wav',
#  'mixed_prwd5p_pwag6n.wav',
#  'mixed_prwd6a_lwiy6n.wav',
#  'mixed_prwd6a_pwag6n.wav',
#  'mixed_prwkza_lwiy6n.wav',
#  'mixed_prwkza_pwag6n.wav',
#  'mixed_prwq3p_lwiy6n.wav',
#  'mixed_prwq3p_pwag6n.wav',
#  'mixed_prwq4a_lwiy6n.wav',
#  'mixed_prwq4a_pwag6n.wav',
#  'mixed_prwx7p_lwiy6n.wav',
#  'mixed_prwx7p_pwag6n.wav',
#  'mixed_pwad1n_lwiy6n.wav',
#  'mixed_pwad1n_pwag6n.wav',
#  'mixed_pwad2s_lwiy6n.wav',
#  'mixed_pwad2s_pwag6n.wav',
#  'mixed_pwad3p_lwiy6n.wav',
#  'mixed_pwad3p_pwag6n.wav',
#  'mixed_pwaj5n_lwiy6n.wav',
#  'mixed_pwaj5n_pwag6n.wav',
#  'mixed_pwap9n_lwiy6n.wav',
#  'mixed_pwap9n_pwag6n.wav',
#  'mixed_pwaqzs_lwiy6n.wav',
#  'mixed_pwaqzs_pwag6n.wav',
#  'mixed_pwax4s_lwiy6n.wav',
#  'mixed_pwax4s_pwag6n.wav',
#  'mixed_pwbd6s_lwiy6n.wav',
#  'mixed_pwbd6s_pwag6n.wav',
#  'mixed_pwbk1p_lwiy6n.wav',
#  'mixed_pwbk1p_pwag6n.wav',
#  'mixed_pwbq3n_lwiy6n.wav',
#  'mixed_pwbq3n_pwag6n.wav',
#  'mixed_pwbq5p_lwiy6n.wav',
#  'mixed_pwbq5p_pwag6n.wav',
#  'mixed_pwbx7n_lwiy6n.wav',
#  'mixed_pwbx7n_pwag6n.wav',
#  'mixed_pwbx8s_lwiy6n.wav',
#  'mixed_pwbx8s_pwag6n.wav',
#  'mixed_pwbx9p_lwiy6n.wav',
#  'mixed_pwbx9p_pwag6n.wav',
#  'mixed_pwbyza_lwiy6n.wav',
#  'mixed_pwbyza_pwag6n.wav',
#  'mixed_pwic8s_lwiy6n.wav',
#  'mixed_pwic8s_pwag6n.wav',
#  'mixed_pwij3p_lwiy6n.wav',
#  'mixed_pwij3p_pwag6n.wav',
#  'mixed_pwip6s_lwiy6n.wav',
#  'mixed_pwip6s_pwag6n.wav',
#  'mixed_pwip7p_lwiy6n.wav',
#  'mixed_pwip7p_pwag6n.wav',
#  'mixed_pwix2a_lwiy6n.wav',
#  'mixed_pwix2a_pwag6n.wav',
#  'mixed_pwixzs_lwiy6n.wav',
#  'mixed_pwixzs_pwag6n.wav',
#  'mixed_pwwd9n_lwiy6n.wav',
#  'mixed_pwwd9n_pwag6n.wav',
#  'mixed_pwwe1p_lwiy6n.wav',
#  'mixed_pwwe1p_pwag6n.wav',
#  'mixed_pwwk3n_lwiy6n.wav',
#  'mixed_pwwk3n_pwag6n.wav',
#  'mixed_pwwk5p_lwiy6n.wav',
#  'mixed_pwwk5p_pwag6n.wav',
#  'mixed_pwwrza_lwiy6n.wav',
#  'mixed_pwwrza_pwag6n.wav',
#  'mixed_pwwy2s_lwiy6n.wav',
#  'mixed_pwwy2s_pwag6n.wav',
#  'mixed_pwwy4a_lwiy6n.wav',
#  'mixed_pwwy4a_pwag6n.wav',
#  'mixed_sbaa3n_lwiy6n.wav',
#  'mixed_sbaa3n_pwag6n.wav',
#  'mixed_sbag8s_lwiy6n.wav',
#  'mixed_sbag8s_pwag6n.wav',
#  'mixed_sban1n_lwiy6n.wav',
#  'mixed_sban1n_pwag6n.wav',
#  'mixed_sban2s_lwiy6n.wav',
#  'mixed_sban2s_pwag6n.wav',
#  'mixed_sbat5n_lwiy6n.wav',
#  'mixed_sbat5n_pwag6n.wav',
#  'mixed_sbat6s_lwiy6n.wav',
#  'mixed_sbat6s_pwag6n.wav',
#  'mixed_sbbh1n_lwiy6n.wav',
#  'mixed_sbbh1n_pwag6n.wav',
#  'mixed_sbbh2s_lwiy6n.wav',
#  'mixed_sbbh2s_pwag6n.wav',
#  'mixed_sbbh3p_lwiy6n.wav',
#  'mixed_sbbh3p_pwag6n.wav',
#  'mixed_sbbh4a_lwiy6n.wav',
#  'mixed_sbbh4a_pwag6n.wav',
#  'mixed_sbbn6s_lwiy6n.wav',
#  'mixed_sbbn6s_pwag6n.wav',
#  'mixed_sbbn8a_lwiy6n.wav',
#  'mixed_sbbn8a_pwag6n.wav',
#  'mixed_sbbu1p_lwiy6n.wav',
#  'mixed_sbbu1p_pwag6n.wav',
#  'mixed_sbbu2a_lwiy6n.wav',
#  'mixed_sbbu2a_pwag6n.wav',
#  'mixed_sbbuzs_lwiy6n.wav',
#  'mixed_sbbuzs_pwag6n.wav',
#  'mixed_sbig3n_lwiy6n.wav',
#  'mixed_sbig3n_pwag6n.wav',
#  'mixed_sbig4s_lwiy6n.wav',
#  'mixed_sbig4s_pwag6n.wav',
#  'mixed_sbim7n_lwiy6n.wav',
#  'mixed_sbim7n_pwag6n.wav',
#  'mixed_sbit4a_lwiy6n.wav',
#  'mixed_sbit4a_pwag6n.wav',
#  'mixed_sbwb3p_lwiy6n.wav',
#  'mixed_sbwb3p_pwag6n.wav',
#  'mixed_sbwb4a_lwiy6n.wav',
#  'mixed_sbwb4a_pwag6n.wav',
#  'mixed_sbwh5n_lwiy6n.wav',
#  'mixed_sbwh5n_pwag6n.wav',
#  'mixed_sbwh7p_lwiy6n.wav',
#  'mixed_sbwh7p_pwag6n.wav',
#  'mixed_sbwh8a_lwiy6n.wav',
#  'mixed_sbwh8a_pwag6n.wav',
#  'mixed_sbwu4s_lwiy6n.wav',
#  'mixed_sbwu4s_pwag6n.wav',
#  'mixed_sbwu5p_lwiy6n.wav',
#  'mixed_sbwu5p_pwag6n.wav',
#  'mixed_sbwu6a_lwiy6n.wav',
#  'mixed_sbwu6a_pwag6n.wav',
#  'mixed_sgac1n_lwiy6n.wav',
#  'mixed_sgac1n_pwag6n.wav',
#  'mixed_sgac2s_lwiy6n.wav',
#  'mixed_sgac2s_pwag6n.wav',
#  'mixed_sgac4a_lwiy6n.wav',
#  'mixed_sgac4a_pwag6n.wav',
#  'mixed_sgai7p_lwiy6n.wav',
#  'mixed_sgai7p_pwag6n.wav',
#  'mixed_sgai8a_lwiy6n.wav',
#  'mixed_sgai8a_pwag6n.wav',
#  'mixed_sgap1p_lwiy6n.wav',
#  'mixed_sgap1p_pwag6n.wav',
#  'mixed_sgav3n_lwiy6n.wav',
#  'mixed_sgav3n_pwag6n.wav',
#  'mixed_sgav4s_lwiy6n.wav',
#  'mixed_sgav4s_pwag6n.wav',
#  'mixed_sgav5p_lwiy6n.wav',
#  'mixed_sgav5p_pwag6n.wav',
#  'mixed_sgbc5n_lwiy6n.wav',
#  'mixed_sgbc5n_pwag6n.wav',
#  'mixed_sgbi9n_lwiy6n.wav',
#  'mixed_sgbi9n_pwag6n.wav',
#  'mixed_sgbj2a_lwiy6n.wav',
#  'mixed_sgbj2a_pwag6n.wav',
#  'mixed_sgbjzs_lwiy6n.wav',
#  'mixed_sgbjzs_pwag6n.wav',
#  'mixed_sgbv7n_lwiy6n.wav',
#  'mixed_sgbv7n_pwag6n.wav',
#  'mixed_sgbv8s_lwiy6n.wav',
#  'mixed_sgbv8s_pwag6n.wav',
#  'mixed_sgbv9p_lwiy6n.wav',
#  'mixed_sgbv9p_pwag6n.wav',
#  'mixed_sgib7n_lwiy6n.wav',
#  'mixed_sgib7n_pwag6n.wav',
#  'mixed_sgii1n_lwiy6n.wav',
#  'mixed_sgii1n_pwag6n.wav',
#  'mixed_sgii3p_lwiy6n.wav',
#  'mixed_sgii3p_pwag6n.wav',
#  'mixed_sgio5n_lwiy6n.wav',
#  'mixed_sgio5n_pwag6n.wav',
#  'mixed_sgio6s_lwiy6n.wav',
#  'mixed_sgio6s_pwag6n.wav',
#  'mixed_sgiu9n_lwiy6n.wav',
#  'mixed_sgiu9n_pwag6n.wav',
#  'mixed_sgwj3n_lwiy6n.wav',
#  'mixed_sgwj3n_pwag6n.wav',
#  'mixed_sgwj4s_lwiy6n.wav',
#  'mixed_sgwj4s_pwag6n.wav',
#  'mixed_sgwj6a_lwiy6n.wav',
#  'mixed_sgwj6a_pwag6n.wav',
#  'mixed_sgwp7n_lwiy6n.wav',
#  'mixed_sgwp7n_pwag6n.wav',
#  'mixed_sgwp9p_lwiy6n.wav',
#  'mixed_sgwp9p_pwag6n.wav',
#  'mixed_sgwx2s_lwiy6n.wav',
#  'mixed_sgwx2s_pwag6n.wav',
#  'mixed_sgwx3p_lwiy6n.wav',
#  'mixed_sgwx3p_pwag6n.wav',
#  'mixed_sraa9n_lwiy6n.wav',
#  'mixed_sraa9n_pwag6n.wav',
#  'mixed_srab1p_lwiy6n.wav',
#  'mixed_srab1p_pwag6n.wav',
#  'mixed_srabzs_lwiy6n.wav',
#  'mixed_srabzs_pwag6n.wav',
#  'mixed_srah3n_lwiy6n.wav',
#  'mixed_srah3n_pwag6n.wav',
#  'mixed_srah4s_lwiy6n.wav',
#  'mixed_srah4s_pwag6n.wav',
#  'mixed_srah6a_lwiy6n.wav',
#  'mixed_srah6a_pwag6n.wav',
#  'mixed_sran7n_lwiy6n.wav',
#  'mixed_sran7n_pwag6n.wav',
#  'mixed_sran8s_lwiy6n.wav',
#  'mixed_sran8s_pwag6n.wav',
#  'mixed_sran9p_lwiy6n.wav',
#  'mixed_sran9p_pwag6n.wav',
#  'mixed_srau1n_lwiy6n.wav',
#  'mixed_srau1n_pwag6n.wav',
#  'mixed_srau2s_lwiy6n.wav',
#  'mixed_srau2s_pwag6n.wav',
#  'mixed_srau3p_lwiy6n.wav',
#  'mixed_srau3p_pwag6n.wav',
#  'mixed_srbb4s_lwiy6n.wav',
#  'mixed_srbb4s_pwag6n.wav',
#  'mixed_srbb5p_lwiy6n.wav',
#  'mixed_srbb5p_pwag6n.wav',
#  'mixed_srbb6a_lwiy6n.wav',
#  'mixed_srbb6a_pwag6n.wav',
#  'mixed_srbh7n_lwiy6n.wav',
#  'mixed_srbh7n_pwag6n.wav',
#  'mixed_srbh8s_lwiy6n.wav',
#  'mixed_srbh8s_pwag6n.wav',
#  'mixed_srbiza_lwiy6n.wav',
#  'mixed_srbiza_pwag6n.wav',
#  'mixed_srbo1n_lwiy6n.wav',
#  'mixed_srbo1n_pwag6n.wav',
#  'mixed_srbu6s_lwiy6n.wav',
#  'mixed_srbu6s_pwag6n.wav',
#  'mixed_srbu7p_lwiy6n.wav',
#  'mixed_srbu7p_pwag6n.wav',
#  'mixed_srbu8a_lwiy6n.wav',
#  'mixed_srbu8a_pwag6n.wav',
#  'mixed_sria5n_lwiy6n.wav',
#  'mixed_sria5n_pwag6n.wav',
#  'mixed_sria8a_lwiy6n.wav',
#  'mixed_sria8a_pwag6n.wav',
#  'mixed_srihzs_lwiy6n.wav',
#  'mixed_srihzs_pwag6n.wav',
#  'mixed_srin3n_lwiy6n.wav',
#  'mixed_srin3n_pwag6n.wav',
#  'mixed_srin4s_lwiy6n.wav',
#  'mixed_srin4s_pwag6n.wav',
#  'mixed_srin5p_lwiy6n.wav',
#  'mixed_srin5p_pwag6n.wav',
#  'mixed_srin6a_lwiy6n.wav',
#  'mixed_srin6a_pwag6n.wav',
#  'mixed_srit7n_lwiy6n.wav',
#  'mixed_srit7n_pwag6n.wav',
#  'mixed_srit8s_lwiy6n.wav',
#  'mixed_srit8s_pwag6n.wav',
#  'mixed_srwcza_lwiy6n.wav',
#  'mixed_srwcza_pwag6n.wav',
#  'mixed_srwo6s_lwiy6n.wav',
#  'mixed_srwo6s_pwag6n.wav',
#  'mixed_srwo8a_lwiy6n.wav',
#  'mixed_srwo8a_pwag6n.wav',
#  'mixed_srwu9n_lwiy6n.wav',
#  'mixed_srwu9n_pwag6n.wav',
#  'mixed_srwv1p_lwiy6n.wav',
#  'mixed_srwv1p_pwag6n.wav',
#  'mixed_srwv2a_lwiy6n.wav',
#  'mixed_srwv2a_pwag6n.wav',
#  'mixed_srwvzs_lwiy6n.wav',
#  'mixed_srwvzs_pwag6n.wav',
#  'mixed_swab5n_lwiy6n.wav',
#  'mixed_swab5n_pwag6n.wav',
#  'mixed_swab6s_lwiy6n.wav',
#  'mixed_swab6s_pwag6n.wav',
#  'mixed_swab7p_lwiy6n.wav',
#  'mixed_swab7p_pwag6n.wav',
#  'mixed_swab8a_lwiy6n.wav',
#  'mixed_swab8a_pwag6n.wav',
#  'mixed_swah9n_lwiy6n.wav',
#  'mixed_swah9n_pwag6n.wav',
#  'mixed_swai1p_lwiy6n.wav',
#  'mixed_swai1p_pwag6n.wav',
#  'mixed_swai2a_lwiy6n.wav',
#  'mixed_swai2a_pwag6n.wav',
#  'mixed_swau7n_lwiy6n.wav',
#  'mixed_swau7n_pwag6n.wav',
#  'mixed_swau9p_lwiy6n.wav',
#  'mixed_swau9p_pwag6n.wav',
#  'mixed_swbc1p_lwiy6n.wav',
#  'mixed_swbc1p_pwag6n.wav',
#  'mixed_swbczs_lwiy6n.wav',
#  'mixed_swbczs_pwag6n.wav',
#  'mixed_swbi3n_lwiy6n.wav',
#  'mixed_swbi3n_pwag6n.wav',
#  'mixed_swbi4s_lwiy6n.wav',
#  'mixed_swbi4s_pwag6n.wav',
#  'mixed_swbo8s_lwiy6n.wav',
#  'mixed_swbo8s_pwag6n.wav',
#  'mixed_swbo9p_lwiy6n.wav',
#  'mixed_swbo9p_pwag6n.wav',
#  'mixed_swbpza_lwiy6n.wav',
#  'mixed_swbpza_pwag6n.wav',
#  'mixed_swbv1n_lwiy6n.wav',
#  'mixed_swbv1n_pwag6n.wav',
#  'mixed_swbv2s_lwiy6n.wav',
#  'mixed_swbv2s_pwag6n.wav',
#  'mixed_swbv3p_lwiy6n.wav',
#  'mixed_swbv3p_pwag6n.wav',
#  'mixed_swib1n_lwiy6n.wav',
#  'mixed_swib1n_pwag6n.wav',
#  'mixed_swih5n_lwiy6n.wav',
#  'mixed_swih5n_pwag6n.wav',
#  'mixed_swih6s_lwiy6n.wav',
#  'mixed_swih6s_pwag6n.wav',
#  'mixed_swih8a_lwiy6n.wav',
#  'mixed_swih8a_pwag6n.wav',
#  'mixed_swiozs_lwiy6n.wav',
#  'mixed_swiozs_pwag6n.wav',
#  'mixed_swiu4s_lwiy6n.wav',
#  'mixed_swiu4s_pwag6n.wav',
#  'mixed_swiu6a_lwiy6n.wav',
#  'mixed_swiu6a_pwag6n.wav',
#  'mixed_swwc5p_lwiy6n.wav',
#  'mixed_swwc5p_pwag6n.wav',
#  'mixed_swwi7n_lwiy6n.wav',
#  'mixed_swwi7n_pwag6n.wav',
#  'mixed_swwi8s_lwiy6n.wav',
#  'mixed_swwi8s_pwag6n.wav',
#  'mixed_swwjza_lwiy6n.wav',
#  'mixed_swwjza_pwag6n.wav',
#  'mixed_swwv5n_lwiy6n.wav',
#  'mixed_swwv5n_pwag6n.wav',
#  'mixed_swwv7p_lwiy6n.wav',
#  'mixed_swwv7p_pwag6n.wav']

# %%
# raw_folder = 'single_dataset_16'
# log_folder = 'test_log'
# phase_folder = 'test_phase'
# a = os.listdir(os.path.join(orig_path,raw_folder))
# a = natsorted(a)
# for filename in a:
#     if filename=='clean':
#         b = os.listdir(os.path.join(orig_path,raw_folder,filename))
#         b = natsorted(b)
#         if not os.path.exists(os.path.join(orig_path,log_folder,filename)):
#             os.mkdir(os.path.join(orig_path,log_folder,filename))
#         for filename2 in b:
#             wav_data, sr = librosa.load(os.path.join(orig_path,raw_folder,filename,filename2), sr=16000)   
#             np.savetxt(os.path.join(orig_path,log_folder,str(filename),str(filename2.replace('.wav','.txt'))), wav_data, delimiter=',')

# %%
# raw_folder = 'sec_mixed2_6_test'
# clean_filename = 'clean_data'
# a = os.listdir(os.path.join(orig_path,raw_folder))
# a = natsorted(a)
# clean=[]
# f = h5py.File(clean_filename+'.hdf5', 'w')
# d = f.create_dataset(clean_filename, (0,257),maxshape=(None,257), dtype='f', chunks=True)
# for filename in a:
#     if filename=='clean':
#         b = os.listdir(os.path.join(orig_path,raw_folder,filename))
#         b = natsorted(b)
#         for i in range(len(a)-1):
#             for filename2 in b:
#                 wav_data, sr = librosa.load(os.path.join(orig_path,raw_folder,filename,filename2), sr=16000)   
#                 framed_data=librosa.core.stft(wav_data, n_fft=512, hop_length=256, win_length=512, window='hann')
#                 abslt=np.absolute(framed_data)**2
#                 dft_signal=np.log10(abslt+1e-7*np.ones(np.shape(abslt)))
# #                 clean.append(dft_signal.T)
#                 d.resize(d.shape[0]+dft_signal.shape[1], axis=0)   
#                 d[-1*dft_signal.shape[1]:] = dft_signal.T
# f.close()
# x=1
# hf = h5py.File('clean_data.h5', 'w')
# hf.create_dataset('clean_data', data=x)
# hf.close()

# %%
a
# Out:
# ['0', '3', '6', 'clean', 'm3', 'm6', 'm9']

# %%
import h5py
h5f = h5py.File('ftr_refrmd_test.hdf5','r')
x = h5f['ftr_refrmd_test']
h5f.close()
x.shape

# %%
import math as m
import numpy as np
import h5py
w = 3
i = 1
refrmd_file = 'ftr_refrmd_train_for_test'
log_folder = 'train_log'
phase_folder = 'train_phase'
# tot_mean=np.loadtxt('mean.txt')
# tot_std=np.loadtxt('std.txt')
a = os.listdir(os.path.join(orig_path,log_folder))
a = natsorted(a)
# # f.close()
# f = h5py.File(refrmd_file+'.hdf5', 'w')
# d = f.create_dataset(refrmd_file, (0,257*w),maxshape=(None,257*w), dtype='f', chunks=True)
ftr_refrmd=[]
if not os.path.exists(os.path.join(orig_path,refrmd_file)):
    os.mkdir(os.path.join(orig_path,refrmd_file))
for filename in a:
    if filename!='clean':
        b = natsorted(b)
        b = os.listdir(os.path.join(orig_path,log_folder,filename))
        if not os.path.exists(os.path.join(orig_path,refrmd_file,filename)):
            os.mkdir(os.path.join(orig_path,refrmd_file,filename))
        for filename2 in b:
            ftr=np.loadtxt(os.path.join(orig_path,log_folder,filename,filename2),delimiter=',')
            ftr_refrmd=[]
            for i in range(m.floor(w/2)):
                p=-m.floor(w/2)
                temp = []
                for j in range(w):
                    if np.all(ftr[i]==0):
                        break
                    temp.extend(ftr[i+p+j])
                if np.any(temp!=[]):
                    ftr_refrmd.append(temp)
            for i in range(m.floor(w/2),ftr.shape[0]-m.floor(w/2)-1):
                k=-m.floor(w/2)
                temp = []
                for j in range(w):
                    if np.all(ftr[i]==0):
                        break
                    temp.extend(ftr[i+k])
                    k=k+1
                if np.any(temp!=[]):
                    ftr_refrmd.append(temp)
                if i%1000==0:
                    print(i)
            for i in range(ftr.shape[0]-m.floor(w/2)-1,ftr.shape[0]):
                p=-m.floor(w/2)
                temp = []
                for j in range(w):
                    if np.all(ftr[i]==0):
                        break
                    if j>m.floor(w/2)+(ftr.shape[0]-i)-1:
                        temp.extend(np.zeros(ftr[ftr.shape[0]-1].shape))
                    else:
                        temp.extend(ftr[i+p+j])
                if np.any(temp!=[]):
                    ftr_refrmd.append(temp)
            print(len(ftr_refrmd[0]))
#             ftr_refrmd=(ftr_refrmd-tot_mean)/tot_std
            np.savetxt(os.path.join(orig_path,refrmd_file,str(filename),str(filename2.replace('.wav','.txt'))), ftr_refrmd, delimiter=',')
            
# d.resize(d.shape[0]+len(ftr_refrmd), axis=0)   
# d[-1*len(ftr_refrmd):] = ftr_refrmd
# ftr_refrmd=[]
# f.close()
# Out:
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771
# 771

# %%
ftr[i+p+j]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-e46e898ce63e> in <module>()
# ----> 1 ftr[i+p+j]
#
# NameError: name 'ftr' is not defined

# %%
len(ftr_refrmd)
# Out:
# 13692

# %%
h5f = h5py.File('ftr_refrmd_test.hdf5','r')
x = h5f['ftr_refrmd_test'][0:]
h5f.close()
x.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-db37f775febe> in <module>()
# ----> 1 h5f = h5py.File('ftr_refrmd_test.hdf5','r')
#       2 x = h5f['ftr_refrmd_test'][0:]
#       3 h5f.close()
#       4 x.shape
#       5
#
# NameError: name 'h5py' is not defined

# %%
len(ftr_refrmd[0])
# Out:
# 771

# %%
f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b5edb7b78a9a> in <module>()
# ----> 1 f.close()
#
# NameError: name 'f' is not defined
